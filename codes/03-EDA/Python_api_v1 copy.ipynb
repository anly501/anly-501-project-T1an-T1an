# %%
import requests
import pandas as pd
import numpy as np
import datetime
pd.set_option('display.float_format',lambda x : '%.4f'%x)
import warnings
warnings.filterwarnings('ignore')
import plotly.graph_objects as go #pip install plotly==5.10.0
import plotly_express as px#pip install plotly_express==0.4.0

# %%
final_v1 = pd.read_csv('/Users/jingdayang/anly-501-project-T1an-T1an/data/01-modified-data/cleaned_currency.csv')
final_v1.head()
# Out:
#          date       open       high        low      close         volume  \
# 0  2021-09-01 47121.0000 49131.0000 46521.0000 48846.0000 484495675.8104
# 1  2021-09-02 48846.0000 50407.0000 48623.0000 49273.0000 602599224.7076
# 2  2021-09-03 49273.0000 51083.0000 48340.0000 50024.0000 781215394.6365
# 3  2021-09-04 50025.0000 50564.0000 49387.0000 49936.0000 360255343.9789
# 4  2021-09-05 49936.0000 51928.0000 49463.0000 51807.0000 435352720.4655
#
#   exchange  M20         M5
# 0  BTC/USD  NaN        NaN
# 1  BTC/USD  NaN        NaN
# 2  BTC/USD  NaN        NaN
# 3  BTC/USD  NaN        NaN
# 4  BTC/USD  NaN 49977.2000

# %%
#all crypto price (except BTC and ETH)
ex_data=final_v1[(final_v1['exchange']!='BTC/USD')&(final_v1['exchange']!='ETH/USD')]
all_price=px.line(data_frame=ex_data,x='date',y='close',color='exchange',title='All Crypto closed Price Over Time(except BTC and ETH)')
all_price.show()

# %%
#BTC price follow

btc=final_v1[(final_v1['exchange']=='BTC/USD')]
btc
fig_btc = go.Figure(go.Candlestick(x=btc.index,
  open=btc['open'],
  high=btc['high'],
  low=btc['low'],
  close=btc['close']))
fig_btc.add_trace(go.Scatter(x=btc.index, 
                         y=btc['M5'], 
                         opacity=0.7, 
                         line=dict(color='blue', width=2), 
                         name='MA5'))
fig_btc.add_trace(go.Scatter(x=btc.index, 
                         y=btc['M20'], 
                         opacity=0.7, 
                         line=dict(color='orange', width=2), 
                         name='MA20'))

fig_btc.update_layout(title="BTC price by FTX")
fig_btc.update_xaxes(title_text="Date", row=1, col=1)
fig_btc.update_yaxes(title_text="Price", row=1, col=1)                     
fig_btc.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/plotly/basedatatypes.py:2329, in BaseFigure._validate_get_grid_ref(self)
#    2328     if grid_ref is None:
# -> 2329         raise AttributeError("_grid_ref")
#    2330 except AttributeError:
#
# AttributeError: _grid_ref
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# /Users/jingdayang/anly-501-project-T1an-T1an/codes/03-EDA/Python_api_v1 copy.ipynb Cell 5 in <cell line: 21>()
#      <a href='vscode-notebook-cell:/Users/jingdayang/anly-501-project-T1an-T1an/codes/03-EDA/Python_api_v1%20copy.ipynb#X13sZmlsZQ%3D%3D?line=13'>14</a> fig_btc.add_trace(go.Scatter(x=btc.index,
#      <a href='vscode-notebook-cell:/Users/jingdayang/anly-501-project-T1an-T1an/codes/03-EDA/Python_api_v1%20copy.ipynb#X13sZmlsZQ%3D%3D?line=14'>15</a>                          y=btc['M20'],
#      <a href='vscode-notebook-cell:/Users/jingdayang/anly-501-project-T1an-T1an/codes/03-EDA/Python_api_v1%20copy.ipynb#X13sZmlsZQ%3D%3D?line=15'>16</a>                          opacity=0.7,
#      <a href='vscode-notebook-cell:/Users/jingdayang/anly-501-project-T1an-T1an/codes/03-EDA/Python_api_v1%20copy.ipynb#X13sZmlsZQ%3D%3D?line=16'>17</a>                          line=dict(color='orange', width=2),
#      <a href='vscode-notebook-cell:/Users/jingdayang/anly-501-project-T1an-T1an/codes/03-EDA/Python_api_v1%20copy.ipynb#X13sZmlsZQ%3D%3D?line=17'>18</a>                          name='MA20'))
#      <a href='vscode-notebook-cell:/Users/jingdayang/anly-501-project-T1an-T1an/codes/03-EDA/Python_api_v1%20copy.ipynb#X13sZmlsZQ%3D%3D?line=19'>20</a> fig_btc.update_layout(title="BTC price by FTX")
# ---> <a href='vscode-notebook-cell:/Users/jingdayang/anly-501-project-T1an-T1an/codes/03-EDA/Python_api_v1%20copy.ipynb#X13sZmlsZQ%3D%3D?line=20'>21</a> fig_btc.update_xaxes(title_text="Date", row=1, col=1)
#      <a href='vscode-notebook-cell:/Users/jingdayang/anly-501-project-T1an-T1an/codes/03-EDA/Python_api_v1%20copy.ipynb#X13sZmlsZQ%3D%3D?line=21'>22</a> fig_btc.update_yaxes(title_text="Price", row=1, col=1)
#      <a href='vscode-notebook-cell:/Users/jingdayang/anly-501-project-T1an-T1an/codes/03-EDA/Python_api_v1%20copy.ipynb#X13sZmlsZQ%3D%3D?line=22'>23</a> fig_btc.show()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/plotly/graph_objs/_figure.py:20822, in Figure.update_xaxes(self, patch, selector, overwrite, row, col, **kwargs)
#   20781 def update_xaxes(
#   20782     self, patch=None, selector=None, overwrite=False, row=None, col=None, **kwargs
#   20783 ):
#   20784     """
#   20785     Perform a property update operation on all xaxis objects
#   20786     that satisfy the specified selection criteria
#    (...)
#   20820         Returns the Figure object that the method was called on
#   20821     """
# > 20822     for obj in self.select_xaxes(selector=selector, row=row, col=col):
#   20823         obj.update(patch, overwrite=overwrite, **kwargs)
#   20825     return self
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/plotly/graph_objs/_figure.py:20745, in Figure.select_xaxes(self, selector, row, col)
#   20715 def select_xaxes(self, selector=None, row=None, col=None):
#   20716     """
#   20717     Select xaxis subplot objects from a particular subplot cell
#   20718     and/or xaxis subplot objects that satisfy custom selection
#    (...)
#   20742         objects that satisfy all of the specified selection criteria
#   20743     """
# > 20745     return self._select_layout_subplots_by_prefix("xaxis", selector, row, col)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/plotly/basedatatypes.py:1416, in BaseFigure._select_layout_subplots_by_prefix(self, prefix, selector, row, col, secondary_y)
#    1409 """
#    1410 Helper called by code generated select_* methods
#    1411 """
#    1413 if row is not None or col is not None or secondary_y is not None:
#    1414     # Build mapping from container keys ('xaxis2', 'scene4', etc.)
#    1415     # to (row, col, secondary_y) triplets
# -> 1416     grid_ref = self._validate_get_grid_ref()
#    1417     container_to_row_col = {}
#    1418     for r, subplot_row in enumerate(grid_ref):
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/plotly/basedatatypes.py:2331, in BaseFigure._validate_get_grid_ref(self)
#    2329         raise AttributeError("_grid_ref")
#    2330 except AttributeError:
# -> 2331     raise Exception(
#    2332         "In order to reference traces by row and column, "
#    2333         "you must first use "
#    2334         "plotly.tools.make_subplots "
#    2335         "to create the figure with a subplot grid."
#    2336     )
#    2337 return grid_ref
#
# Exception: In order to reference traces by row and column, you must first use plotly.tools.make_subplots to create the figure with a subplot grid.

# %%
#ETH price follow
eth=final_v1[(final_v1['exchange']=='ETH/USD')]
fig_eth = go.Figure(go.Candlestick(x=eth.index,
  open=eth['open'],
  high=eth['high'],
  low=eth['low'],
  close=eth['close']))
fig_eth.add_trace(go.Scatter(x=eth.index, 
                         y=eth['M5'], 
                         opacity=0.7, 
                         line=dict(color='blue', width=2), 
                         name='MA 5'))
fig_eth.add_trace(go.Scatter(x=eth.index, 
                         y=eth['M20'], 
                         opacity=0.7, 
                         line=dict(color='orange', width=2), 
                         name='MA 20'))
fig_eth.show()
